# %%
l1 = ["a","b","c"]

# %%
l2 = l1

# %%
l2
# Out:
# ['a', 'b', 'c']

# %%
l2[0] = 1

# %%
l2
# Out:
# [1, 'b', 'c']

# %%
l1
# Out:
# [1, 'b', 'c']

# %%
# cloning

# %%
list_1 = [1,2,3]

# %%
list_2 = list_1.copy()

# %%
list_2
# Out:
# [1, 2, 3]

# %%
list_2[0] = 4

# %%
list_2
# Out:
# [4, 2, 3]

# %%
list_1
# Out:
# [1, 2, 3]

# %%
student_1 = [1,2,3,[4,5,6]]

# %%
student_2 = student_1.copy()

# %%
student_2[-1][0] = 7

# %%
student_2
# Out:
# [1, 2, 3, [7, 5, 6]]

# %%
student_1
# Out:
# [1, 2, 3, [7, 5, 6]]

# %%
id(student_2[-1])
# Out:
# 2498724292736

# %%
id(student_1[-1])
# Out:
# 2498724292736

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Deep Copy

# %%
import copy

# %%
student_1
# Out:
# [1, 2, 3, [7, 5, 6]]

# %%
student_2
# Out:
# [1, 2, 3, [7, 5, 6]]

# %%
student_3 = copy.deepcopy(student_1)

# %%
student_3
# Out:
# [1, 2, 3, [7, 5, 6]]

# %%
id(student_3)
# Out:
# 2498748880256

# %%
id(student_2)
# Out:
# 2498745442752

# %%
id(student_1)
# Out:
# 2498745387584

# %%
id(student_3[-1][0])
# Out:
# 2498645328304

# %%
id(student_2[-1][0])
# Out:
# 2498645328304

# %%
# clear

# %%
list_1.clear()

# %%
list_1
# Out:
# []

# %%
# List Comprehension

# %%
l3 = [5,2,-1,6,4]

# %%
l3
# Out:
# [5, 2, -1, 6, 4]

# %%
l4=[]
for i in l3:
    square = i ** 2
    l4.append(square)
print(l4)
# Out:
# [25, 4, 1, 36, 16]

# %%
res = [i**2 for i in l3]

# %%
res
# Out:
# [25, 4, 1, 36, 16]
