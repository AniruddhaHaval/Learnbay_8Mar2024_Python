# %%
fh_1 = open('file2.txt','xt')

# %%
fh_1.write("Hello xt mode")
# Out:
# 13

# %%
fh_1.close()

# %%
# w mode on a new file name creates a file and opens it for writing!

# %%
fh = open('file1.txt','wt')

# %%
fh.write("Hello\n")
# Out:
# 6

# %%
fh.write("Aniruddha\n")
# Out:
# 10

# %%
fh.close()

# %%
import os

# %%
os.path.exists("file2.txt")
# Out:
# True

# %%
os.path.exists("file4.txt")
# Out:
# False

# %%
# 'a' mode > append

# %%
fh = open('file1.txt','at')

# %%
fh.write('Good Evening')
# Out:
# 12

# %%
fh.close()

# %%
fh = open('file5.txt','at')

# %%
fh.write("creates new file and append in new file")
# Out:
# 39

# %%
fh.close()

# %%
fh_1 = open('file2.txt','rt')

# %%
help(fh_1.read)
# Out:
# Help on built-in function read:
#
# read(size=-1, /) method of _io.TextIOWrapper instance
#     Read at most n characters from stream.
#
#     Read from underlying buffer until we have n characters or we hit EOF.
#     If n is negative or omitted, read until EOF.

# %%
fh_1.read(5)
# Out:
# 'Hello'

# %%
fh_1.read()
# Out:
# ' xt mode'

# %%
fh_1.read()
# Out:
# ''

# %%
content = fh_1.read()

# %%
print(content)

# %%
fh = open('file1.txt','rt')

# %%
fh.readline()
# Out:
# 'Hello\n'

# %%
fh.readline()
# Out:
# 'Aniruddha\n'

# %%
fh.readline()
# Out:
# 'Good Evening'

# %%
fh.readline()
# Out:
# ''

# %%
# readlines

# %%
fh = open('file1.txt','rt')

# %%
fh.readlines()
# Out:
# ['Hello\n', 'Aniruddha\n', 'Good Evening']

# %%
fh.readlines()
# Out:
# []

# %%
fh = open('file1.txt','rt')

# %%
lines = fh.readlines()

# %%
lines
# Out:
# ['Hello\n', 'Aniruddha\n', 'Good Evening']

# %%
for line in lines:
    print(line.count('e'))
# Out:
# 1
# 0
# 1

# %%
fh.close()

# %%
# binary files

# %%
fh = open('wallpaper.jpg', 'rb')

# %%
fh.read()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\xff\xed\x00\x9cPhotoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x00\x80\x1c\x02g\x00\x14E8ezaVrFW-Cx8GDs63oR\x1c\x02(\x00bFBMD01000a9e0d0000c49000009f56010006690100d6970100499a0200db410400ae5e04009f870400eed70400efbd0700\xff\xe2\x0b\xf8ICC_PROFILE\x00\x01\x01\x00\x00\x0b\xe8\x00\x00\x00\x00\x02\x00\x00\x00mntrRGB XYZ \x07\xd9\x00\x03\x00\x1b\x00\x15\x00$\x00\x1facsp\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-\x00\x00\x00\x00)\xf8=\xde\xaf\xf2U\xaexB\xfa\xe4\xca\x839\r\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10desc\x00\x00\x01D\x00\x00\x00ybXYZ\x00\x00\x01\xc0\x00\x00\x00\x14bTRC\x00\x00\x01\xd4\x00\x00\x08\x0cdmdd\x00\x00\t\xe0\x00\x00\x00\x88gXYZ\x00\x00\nh\x00\x00\x00\x14gTRC\x00\x00\x01\xd4\x00\x00\x08\x0clumi\x00\x00\n
# ...

# %%
fh = open('C:/Users/pc/Documents/Learnbay_8Mar2024_Python/19_Apr_2024/wallpaper.jpg', 'rb')

# %%
contents = fh.read()

# %%
fh.close()

# %%
contents
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\xff\xed\x00\x9cPhotoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x00\x80\x1c\x02g\x00\x14E8ezaVrFW-Cx8GDs63oR\x1c\x02(\x00bFBMD01000a9e0d0000c49000009f56010006690100d6970100499a0200db410400ae5e04009f870400eed70400efbd0700\xff\xe2\x0b\xf8ICC_PROFILE\x00\x01\x01\x00\x00\x0b\xe8\x00\x00\x00\x00\x02\x00\x00\x00mntrRGB XYZ \x07\xd9\x00\x03\x00\x1b\x00\x15\x00$\x00\x1facsp\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-\x00\x00\x00\x00)\xf8=\xde\xaf\xf2U\xaexB\xfa\xe4\xca\x839\r\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x10desc\x00\x00\x01D\x00\x00\x00ybXYZ\x00\x00\x01\xc0\x00\x00\x00\x14bTRC\x00\x00\x01\xd4\x00\x00\x08\x0cdmdd\x00\x00\t\xe0\x00\x00\x00\x88gXYZ\x00\x00\nh\x00\x00\x00\x14gTRC\x00\x00\x01\xd4\x00\x00\x08\x0clumi\x00\x00\n
# ...

# %%
type(contents)
# Out:
# bytes

# %%
type(content)
# Out:
# str

# %%
fh = open('wallpaper.jpg', 'wb')

# %%
fh.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 fh.read()
#
# UnsupportedOperation: read

# %%
# creating a binary file

# %%
fh = open('file6.bin', 'xb')

# %%
fh.write("Hello")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 fh.write("Hello")
#
# TypeError: a bytes-like object is required, not 'str'

# %%
fh.write(b"Hello")
# Out:
# 5

# %%
fh.close()

# %%
# copy

# %%
fh_2 = open('file1.txt', 'rt')

# %%
fh_3 = open('file7.txt', 'xt')

# %%
contents = fh_2.read()

# %%
contents
# Out:
# 'Hello\nAniruddha\nGood Evening'

# %%
fh_3.write(contents)
# Out:
# 28

# %%
fh_2.close()

# %%
fh_3.close()
